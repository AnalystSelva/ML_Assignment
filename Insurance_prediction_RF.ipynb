# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset.shape[0]
# Out:
# 1338

# %%
dataset.shape[1]
# Out:
# 6

# %%
one_hot_encoding = pd.get_dummies(dataset)
one_hot_encoding = one_hot_encoding.astype(int)
one_hot_encoding.head()
# Out:
#    age  bmi  children  charges  sex_female  sex_male  smoker_no  smoker_yes
# 0   19   27         0    16884           1         0          0           1
# 1   18   33         1     1725           0         1          1           0
# 2   28   33         3     4449           0         1          1           0
# 3   33   22         0    21984           0         1          1           0
# 4   32   28         0     3866           0         1          1           0

# %%
one_hot_encoding.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'smoker_no', 'smoker_yes'],
#       dtype='object')

# %%
independent = one_hot_encoding[['age', 'bmi', 'children','sex_female', 'sex_male',
       'smoker_no', 'smoker_yes']]
independent
# Out:
#       age  bmi  children  sex_female  sex_male  smoker_no  smoker_yes
# 0      19   27         0           1         0          0           1
# 1      18   33         1           0         1          1           0
# 2      28   33         3           0         1          1           0
# 3      33   22         0           0         1          1           0
# 4      32   28         0           0         1          1           0
# ...   ...  ...       ...         ...       ...        ...         ...
# 1333   50   30         3           0         1          1           0
# 1334   18   31         0           1         0          1           0
# 1335   18   36         0           1         0          1           0
# 1336   21   25         0           1         0          1           0
# 1337   61   29         0           1         0          0           1
#
# [1338 rows x 7 columns]

# %%
dependent = one_hot_encoding[['charges']]
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test = train_test_split(independent, dependent, test_size=0.3, random_state=0)

# %%
x_train , y_train
# Out:
# (      age  bmi  children  sex_female  sex_male  smoker_no  smoker_yes
#  1163   18   28         0           1         0          1           0
#  196    39   32         0           1         0          1           0
#  438    52   46         5           1         0          1           0
#  183    44   26         0           1         0          1           0
#  1298   33   27         2           0         1          1           0
#  ...   ...  ...       ...         ...       ...        ...         ...
#  763    27   26         0           0         1          1           0
#  835    42   35         2           0         1          1           0
#  1216   40   25         0           0         1          1           0
#  559    19   35         0           0         1          1           0
#  684    33   18         1           1         0          1           0
#
#  [936 rows x 7 columns],
#        charges
#  1163     2200
#  196      5649
#  438     12592
#  183      7419
#  1298     5261
#  ...       ...
#  763      3070
#  835      7160
#  1216     5415
#  559      1646
#  684      4766
#
#  [936 rows x 1 columns])

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %%
x_train = sc.fit_transform(x_train)

# %%
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regression = RandomForestRegressor(n_estimators=100,criterion='absolute_error',max_features='sqrt')
regression
# Out:
# RandomForestRegressor(criterion='absolute_error', max_features='sqrt')

# %%
regression.fit(x_train,y_train)
# Out:
# C:\Users\Selva\miniforge3\lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(criterion='absolute_error', max_features='sqrt')

# %%
y_pred = regression.predict(x_test)
y_pred
# Out:
# array([10926.11 ,  9075.405, 43308.39 , 13005.305, 10894.855, 11858.56 ,
#         2254.735, 11172.335,  7989.82 ,  6172.48 ,  6210.565, 11560.26 ,
#         8018.4  ,  5628.64 , 22847.405, 11472.49 , 12442.215,  4048.7  ,
#         7607.93 , 31871.465, 26413.665, 15915.565, 12313.425, 25025.89 ,
#         4683.83 ,  7928.735,  3692.035,  8512.735,  3978.755, 12100.615,
#         6830.795,  3000.26 ,  2398.395,  8323.465, 13295.835,  9248.505,
#         6919.125,  7224.99 , 12184.845, 34595.29 ,  6279.2  , 11697.815,
#         5568.705, 34962.08 , 10958.715,  8178.525,  9956.625, 11442.225,
#         3604.49 ,  8147.845,  6901.09 ,  5906.46 , 20000.75 , 44353.425,
#         5850.175,  6888.41 ,  5012.62 ,  2310.15 ,  8588.185,  3906.28 ,
#         5589.515, 10141.1  ,  9497.99 , 25210.93 , 43202.95 , 15630.655,
#         6416.41 , 11245.935, 39309.535, 10484.74 , 38832.825,  1460.13 ,
#        36603.86 ,  5808.535, 12657.52 ,  9713.845, 38004.33 ,  5268.685,
#         9964.69 ,  9437.05 ,  6161.88 , 14930.545, 11725.24 , 10893.69 ,
#        16365.62 ,  7018.47 ,  7392.685,  4130.465,  8509.31 , 21794.895,
#         4610.105,  1981.31 ,  3206.215, 45309.31 , 11019.705,  4619.125,
#        16394.195, 13770.85 , 33212.71 ,  7742.775,  5733.18 ,  8777.625,
#         2852.52 ,  5474.2  , 19255.2  , 18249.225, 14079.945,  2952.51 ,
#         4011.08 , 10726.155,  9684.72 , 18790.81 , 20568.975,  7340.16 ,
#        19101.96 ,  2820.825,  6751.44 ,  9783.89 , 14938.165,  3327.4  ,
#         8669.525, 46367.44 ,  5273.66 ,  5895.075,  3007.88 , 12798.555,
#         3868.65 , 11748.225, 42848.96 , 20141.845,  9497.05 , 39551.17 ,
#        19794.775, 13277.055, 10171.8  ,  4737.675, 32121.13 ,  4776.155,
#        14461.65 ,  2983.92 , 18137.975,  3976.49 , 28191.16 ,  6345.45 ,
#         2980.715, 38008.82 ,  8923.205,  5329.46 , 33556.915,  2852.52 ,
#         9697.68 ,  3546.905, 11545.505,  4222.835,  6792.57 ,  7085.33 ,
#        41773.535, 11368.495, 36243.22 , 36878.13 ,  6279.2  ,  7995.97 ,
#         1981.195,  4994.02 ,  4775.775,  9183.455, 45053.8  , 10993.285,
#         2837.815, 11830.905,  2415.325, 14410.675,  9388.34 ,  2511.3  ,
#         5386.11 , 35211.05 ,  6432.18 ,  2314.325, 38640.61 , 11418.525,
#        43663.05 , 11387.685,  6523.815,  2745.225,  2487.99 , 11894.79 ,
#         5382.89 ,  2374.03 , 11144.095,  7397.53 ,  6911.005,  9487.595,
#         8254.99 , 39386.04 ,  7837.85 , 17947.915,  5676.365, 16761.455,
#        11491.155,  7224.11 , 18869.82 , 13132.395, 16703.355, 19021.94 ])

# %%
from sklearn.metrics import r2_score

# %%
r2_score = r2_score(y_test, y_pred)
r2_score
# Out:
# 0.8653919530597932

# %%
import pickle

# %%
file_name = "RF_Algorith_For_Insurance.sav"
pickle.dump(regression,open(file_name,'wb'))

# %%
load = pickle.load(open(file_name,'rb'))
result = load.predict([[90,30,3,1,0,0,1]])
result
# Out:
# array([30684.145])
